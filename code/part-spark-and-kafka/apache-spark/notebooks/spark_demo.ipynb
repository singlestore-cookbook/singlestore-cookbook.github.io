# %% [markdown]
# # Spark Demo

# %%
# !pip cache purge --quiet

# %%
# !pip install install-jdk==1.1.0 \
             pyspark==4.0.0 --quiet

# %%
import jdk
import os

from pyspark.sql import SparkSession

os.environ.pop("CONTAINER_ID", None)
# Out:
# '6fe371a7-bd05-45ac-893b-50364d09fbf2'

# %%
# Configure Java
jdk_path = jdk.install("17")

os.environ["JAVA_HOME"] = jdk_path
os.environ["PATH"] = f"{jdk_path}/bin:" + os.environ["PATH"]

# %%
# Create a Spark session
spark = (
    SparkSession.builder
    .appName("Spark Demo")
    .master("local[*]")
    .getOrCreate()
)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/08 13:21:35 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Create a DataFrame
data = [("Peter", 27), ("Paul", 28), ("Mary", 29)]
df = spark.createDataFrame(data, ["Name", "Age"])

# %%
# Show the content of the DataFrame
df.show()
# Out:
# +-----+---+
# | Name|Age|
# +-----+---+
# |Peter| 27|
# | Paul| 28|
# | Mary| 29|
# +-----+---+

# %%
# Stop the Spark session
spark.stop()
